# %%
import pandas as pd
import matplotlib.pyplot as plt
import descartes
import geopandas as gpd
from shapely.geometry import Point, Polygon

# %matplotlib inline

# %%
world_map = gpd.read_file('world.shp')

# %%
df = pd.read_csv('COVID-19.csv')
crs = {'init': 'epsg:4326'}

# %%
geometry = [Point(xy) for xy in zip(df['Long'], df['Lat'])]

# %%
geo_df = gpd.GeoDataFrame(df,
                         crs = crs,
                         geometry = geometry)

# %%
fig, ax = plt.subplots(figsize = (20,20))
world_map.plot(ax = ax, alpha = 0.4, color = 'skyblue')
i = 4
geo_df[geo_df['Confirmed']<50].plot(ax=ax, markersize=i, c = 'green', marker = "o", label='less than 50 cases')
geo_df[geo_df['Confirmed']>50].plot(ax=ax, markersize=i, color = 'steelblue', marker = "o", label='more than 50 cases')
geo_df[geo_df['Confirmed']>100].plot(ax=ax, markersize=i, color = 'blue', marker = "o", label='more than 100 case')
geo_df[geo_df['Confirmed']>150].plot(ax=ax, markersize=i, color = 'yellow', marker = "o", label='more than 150 cases')
geo_df[geo_df['Confirmed']>200].plot(ax=ax, markersize=i, color = 'purple', marker = "o", label='more than 200 cases')
geo_df[geo_df['Confirmed']>250].plot(ax=ax, markersize=i, color = 'red', marker = "o", label='more than 250 cases')
geo_df[geo_df['Confirmed']>300].plot(ax=ax, markersize=i, color = 'pink', marker = "o", label='more than 300 cases')
geo_df[geo_df['Confirmed']>500].plot(ax=ax, markersize=i, color = 'brown', marker = "o", label= 'more than 500 cases')
geo_df[geo_df['Confirmed']>1000].plot(ax=ax, markersize=i, color = 'black', marker = "o", label= 'more than 1000 cases')
geo_df[geo_df['Confirmed']>2000].plot(ax=ax, markersize=i, color = 'orange', marker = "o", label= 'more than 2000 cases')




plt.title("# of cases", size = 25)
plt.legend(prop={'size':15})

# %%
fig, ax = plt.subplots(figsize = (20,20))
world_map.plot(ax = ax, alpha = 0.4, color = 'skyblue')
i = 5
geo_df[geo_df['Deaths']==0].plot(ax=ax, markersize=i, color = 'white', marker = "o", label='0 Deaths')
geo_df[geo_df['Deaths']>0].plot(ax=ax, markersize=i, color = 'green', marker = "o", label='less than 15 Deaths')
geo_df[geo_df['Deaths']>15].plot(ax=ax, markersize=i, color = 'steelblue', marker = "o", label='more than 15 Deaths')
geo_df[geo_df['Deaths']>50].plot(ax=ax, markersize=i, color = 'blue', marker = "o", label='more than 50 Deaths')
geo_df[geo_df['Deaths']>100].plot(ax=ax, markersize=i, color = 'yellow', marker = "o", label='more than 100 Deaths')
geo_df[geo_df['Deaths']>200].plot(ax=ax, markersize=i, color = 'purple', marker = "o", label='more than 200 Deaths')
geo_df[geo_df['Deaths']>250].plot(ax=ax, markersize=i, color = 'red', marker = "o", label='more than 250 Deaths')
geo_df[geo_df['Deaths']>300].plot(ax=ax, markersize=i, color = 'pink', marker = "o", label='more than 300 Deaths')
geo_df[geo_df['Deaths']>500].plot(ax=ax, markersize=i, color = 'brown', marker = "o", label= 'more than 500 Deaths')
geo_df[geo_df['Deaths']>700].plot(ax=ax, markersize=i, color = 'black', marker = "o", label= 'more than 700 Deaths')
geo_df[geo_df['Deaths']>1000].plot(ax=ax, markersize=i, color = 'orange', marker = "o", label= 'more than 1000 Deaths')




plt.title("# of Deaths", size = 25)
plt.legend(prop={'size':15})

# %%
fig, ax = plt.subplots(figsize = (20,20))
world_map.plot(ax = ax, alpha = 0.4, color = 'skyblue')
i = 5
geo_df[geo_df['Recovered']==0].plot(ax=ax, markersize=i, color = 'white', marker = "o", label='0 Recovered')
geo_df[geo_df['Recovered']>0].plot(ax=ax, markersize=i, color = 'green', marker = "o", label='less than 15 Recovered')
geo_df[geo_df['Recovered']>10].plot(ax=ax, markersize=i, color = 'steelblue', marker = "o", label='more than 15 Recovered')
geo_df[geo_df['Recovered']>25].plot(ax=ax, markersize=i, color = 'blue', marker = "o", label='more than 50 Recovered')
geo_df[geo_df['Recovered']>50].plot(ax=ax, markersize=i, color = 'yellow', marker = "o", label='more than 100 Recovered')
geo_df[geo_df['Recovered']>100].plot(ax=ax, markersize=i, color = 'purple', marker = "o", label='more than 200 Recovered')
geo_df[geo_df['Recovered']>250].plot(ax=ax, markersize=i, color = 'red', marker = "o", label='more than 250 Recovered')
geo_df[geo_df['Recovered']>500].plot(ax=ax, markersize=i, color = 'pink', marker = "o", label='more than 300 Recovered')
geo_df[geo_df['Recovered']>700].plot(ax=ax, markersize=i, color = 'brown', marker = "o", label= 'more than 500 Recovered')
geo_df[geo_df['Recovered']>1000].plot(ax=ax, markersize=i, color = 'black', marker = "o", label= 'more than 700 Recovered')
geo_df[geo_df['Recovered']>2000].plot(ax=ax, markersize=i, color = 'orange', marker = "o", label= 'more than 1000 Recovered')




plt.title("# Recovered", size = 25)
plt.legend(prop={'size':15})
